# %% [markdown]
# # REGRESSION

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/drive/MyDrive/Dataset ML/real_estate_price_size.csv")

# %%
data.isna().sum()
# Out:
# price    0
# size     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   100 non-null    float64
#  1   size    100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
import matplotlib.pyplot as plt
plt.scatter(data['size'], data['price'], color='red')
plt.title('Scatter Plot: Size vs Price')
plt.xlabel('Size ')
plt.ylabel('Price')
plt.show()

# %%
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %%
x = data[['size']]
y = data['price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 108544.7701369999
# [218.98817817]

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.6907868549524642

# %%
regressor.predict([[643.09]])
# Out:
# array([249373.87763466])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_pred,color="black")

# %%
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import root_mean_squared_error as RMSE

print("MAE : ",MAE(y_test,y_pred))
print("MSE : ",MSE(y_test,y_pred))
print("RMSE : ",RMSE(y_test,y_pred))
# Out:
# MAE :  35120.39482198923
# MSE :  1625072496.2111764
# RMSE :  40312.1879362951
